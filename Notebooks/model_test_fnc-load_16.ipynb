# %%
# %config IPCompleter.greedy=True
from IPython.display import IFrame

import pandas as pd
import numpy as np
import string
import math

import scipy.stats as sts

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

from sklearn import preprocessing as prep
import sklearn.metrics as metrics
import sklearn.model_selection as model_selection
from sklearn import discriminant_analysis as disan
from sklearn import calibration as calib
from sklearn import linear_model as lm
from sklearn import svm
from sklearn import gaussian_process as gaup
from sklearn import mixture as mix
from sklearn import tree
from sklearn import ensemble as ens

import tensorflow as tf
from tensorflow import keras

# from keras import models as kermdls
# from keras import layers as kerlrs
# from keras import metrics as kmetrics

from hyperas import optim
from hyperas.distributions import choice, uniform
from hyperopt import Trials, STATUS_OK, tpe

import pickle

import nilearn as nl
from nilearn import plotting, image
from nilearn import datasets
import nibabel as nb
import h5py

import os

import time
# Out:
# Using TensorFlow backend.

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU')]

# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16183474454924975064
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7596457816119993730
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6589725830
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14990521472743749202
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6512076630308625694
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
TEST_IDS = [map_id.split('.')[0] for map_id in sorted(os.listdir('00_Data/fMRI_test'))]
TRAIN_IDS = [map_id.split('.')[0] for map_id in sorted(os.listdir('00_Data/fMRI_train'))]

# %%
data = pd.read_csv('00_Data/train_scores.csv')
data
# Out:
#          Id        age  domain1_var1  domain1_var2  domain2_var1  domain2_var2
# 0     10001  57.436077     30.571975     62.553736     53.325130     51.427998
# 1     10002  59.580851     50.969456     67.470628     60.651856     58.311361
# 2     10004  71.413018     53.152498     58.012103     52.418389     62.536641
# 3     10005  66.532630           NaN           NaN     52.108977     69.993075
# 4     10007  38.617381     49.197021     65.674285     40.151376     34.096421
# ...     ...        ...           ...           ...           ...           ...
# 5872  21746  14.257265     21.358872     61.165998     51.778483     54.640179
# 5873  21747  55.456978     68.169675     29.907995     55.349257     54.019517
# 5874  21750  48.948756     55.114811     60.878271     38.617246     50.679885
# 5875  21752  66.532630     59.844808     72.303110     55.458281     46.870235
# 5876  21754  68.820928     56.594193     34.605868     49.922535     50.383078
#
# [5877 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Id                0
# age               0
# domain1_var1    438
# domain1_var2    438
# domain2_var1     39
# domain2_var2     39
# dtype: int64

# %%
data = data.dropna()

# %%
print('Dataset length: ', len(data.index))
# Out:
# Dataset length:  5434

# %%
def get_inputs(idx, labels):
    df_fnc = pd.read_csv('00_Data/fnc_csv/{0}.csv'.format(idx), index_col=0)
    X_fnc = np.array(df_fnc.values).reshape(-1)
    
    df_loading = pd.read_csv('00_Data/loading_csv/{0}.csv'.format(idx), index_col=0)
    X_loading = np.array(df_loading.values).reshape(-1)

    X = np.concatenate((X_fnc, X_loading))
#     print(len(X))
    return X, labels

# %%
def new_py_function(func, inp, Tout, name=None):
    
    def wrapped_func(*flat_inp):
        reconstructed_inp = tf.nest.pack_sequence_as(inp, flat_inp,
                                                     expand_composites=True)
        out = func(*reconstructed_inp)
        return tf.nest.flatten(out, expand_composites=True)
    
    flat_Tout = tf.nest.flatten(Tout, expand_composites=True)
    flat_out = tf.py_function(func=wrapped_func, 
                              inp=tf.nest.flatten(inp, expand_composites=True),
                              Tout=[_tensor_spec_to_dtype(v) for v in flat_Tout],
                              name=name)
    spec_out = tf.nest.map_structure(_dtype_to_tensor_spec, Tout, expand_composites=True)
    out = tf.nest.pack_sequence_as(spec_out, flat_out, expand_composites=True)
    return out

def _dtype_to_tensor_spec(v):
    return tf.TensorSpec(None, v) if isinstance(v, tf.dtypes.DType) else v

def _tensor_spec_to_dtype(v):
    return v.dtype if isinstance(v, tf.TensorSpec) else v

# %%
def get_dataset(data, batch_size):
    data = tf.data.Dataset.from_tensor_slices((data['Id'].values, 
                                               data[['age', 'domain1_var1', 'domain1_var2', 'domain2_var1', 'domain2_var2']].values))
    data = data.shuffle(buffer_size=5500, seed=30, reshuffle_each_iteration=True)
    
    data = data.map(lambda idx, lbl:new_py_function(get_inputs, inp=(idx, lbl), Tout=(tf.float64, tf.float64), name=None), 
                     num_parallel_calls=tf.data.experimental.AUTOTUNE, 
                     deterministic=True)
    data = data.batch(batch_size, drop_remainder=True)
    data = data.prefetch(tf.data.experimental.AUTOTUNE)
    return data

# %%
train, test = model_selection.train_test_split(data, test_size=0.2, shuffle=True, random_state=30)
train, val = model_selection.train_test_split(train, test_size=0.2, shuffle=True, random_state=30)

# %%
batch_size = 64

ds_train = get_dataset(train, batch_size)
ds_val = get_dataset(val, batch_size)
ds_test = get_dataset(test, batch_size)

# %%
INPUT_SHAPE = (1404,)

# %%
inputs = keras.layers.Input(shape=INPUT_SHAPE, name='inp')

x = keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, 
                                          beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros',
                                          moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, 
                                          beta_constraint=None, gamma_constraint=None)(inputs)
x = keras.layers.Dense(2048,
                           kernel_initializer=keras.initializers.he_normal(seed=30),
                           bias_initializer=keras.initializers.Constant(5.))(x)
x = tf.keras.layers.PReLU(alpha_initializer=keras.initializers.Constant(0.5))(x)
x = keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, 
                                          beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros',
                                          moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, 
                                          beta_constraint=None, gamma_constraint=None)(x)


x1 = keras.layers.Dense(512,
                           kernel_initializer=keras.initializers.he_normal(seed=30),
                           bias_initializer=keras.initializers.Constant(5.))(x)
x1 = tf.keras.layers.PReLU(alpha_initializer=keras.initializers.Constant(0.5))(x1)
x1 = keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, 
                                          beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros',
                                          moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, 
                                          beta_constraint=None, gamma_constraint=None)(x1)

x2 = keras.layers.Dense(512,
                           kernel_initializer=keras.initializers.he_normal(seed=30),
                           bias_initializer=keras.initializers.Constant(5.))(x)
x2 = tf.keras.layers.PReLU(alpha_initializer=keras.initializers.Constant(0.5))(x2)
x2 = keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, 
                                          beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros',
                                          moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, 
                                          beta_constraint=None, gamma_constraint=None)(x2)

x = keras.layers.concatenate([x1, x2])

x = keras.layers.Dense(1024,
                           kernel_initializer=keras.initializers.he_normal(seed=30),
                           bias_initializer=keras.initializers.Constant(5.))(x)
x = tf.keras.layers.PReLU(alpha_initializer=keras.initializers.Constant(0.5))(x)
x = keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, 
                                          beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros',
                                          moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, 
                                          beta_constraint=None, gamma_constraint=None)(x)

z1 = keras.layers.Dense(1024, 
                       kernel_initializer=keras.initializers.he_normal(seed=30),
                       bias_initializer=keras.initializers.Constant(5.))(x)
z1 = tf.keras.layers.PReLU(alpha_initializer=keras.initializers.Constant(0.5))(z1)
z1 = keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, 
                                          beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros',
                                          moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, 
                                          beta_constraint=None, gamma_constraint=None)(z1)

z2 = keras.layers.Dense(1024, 
                       kernel_initializer=keras.initializers.he_normal(seed=30),
                       bias_initializer=keras.initializers.Constant(5.))(x)
z2 = tf.keras.layers.PReLU(alpha_initializer=keras.initializers.Constant(0.5))(z2)
z2 = keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, 
                                          beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros',
                                          moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, 
                                          beta_constraint=None, gamma_constraint=None)(z2)

z = keras.layers.concatenate([z1, z2])

z = keras.layers.Dense(2048, 
                       kernel_initializer=keras.initializers.he_normal(seed=30),
                       bias_initializer=keras.initializers.Constant(5.))(z)
z = tf.keras.layers.PReLU(alpha_initializer=keras.initializers.Constant(0.5))(z)

outputs = keras.layers.Dense(5, activation='linear')(z)

model = keras.Model(inputs=inputs, outputs=outputs, name='model_combined')

# %%
model.summary()
# Out:
# Model: "model_combined"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inp (InputLayer)                [(None, 1404)]       0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1404)         5616        inp[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         2877440     batch_normalization[0][0]
# __________________________________________________________________________________________________
# p_re_lu (PReLU)                 (None, 2048)         2048        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 2048)         8192        p_re_lu[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          1049088     batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          1049088     batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 512)          512         dense_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 512)          512         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          2048        p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1024)         0           batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         1049600     concatenate[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 1024)         1024        dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1024)         4096        p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         1049600     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1024)         1049600     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 1024)         1024        dense_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 1024)         1024        dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1024)         4096        p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1024)         4096        p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2048)         0           batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2048)         4196352     concatenate_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 2048)         2048        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 5)            10245       p_re_lu_6[0][0]
# ==================================================================================================
# Total params: 12,369,397
# Trainable params: 12,354,301
# Non-trainable params: 15,096
# __________________________________________________________________________________________________

# %%
# optim = keras.optimizers.Adam(lr=0.000001,
#                                  beta_1=0.99,
#                                  beta_2=0.999,
#                                  amsgrad=False)

optim = tf.keras.optimizers.Adadelta(learning_rate=0.001, rho=0.95)
        
METRICS = [keras.metrics.RootMeanSquaredError(name='rmse'),
           keras.metrics.MeanSquaredError(name='mse'),
           keras.metrics.MeanAbsoluteError(name='mae')]

# %%
model.compile(loss='mae', metrics=METRICS, optimizer=optim)

# %%
checkpoint_prefix = os.path.join('./99_Training_checkpoints/fnc-loading', "ckpt_{epoch}")

callbacks = [tf.keras.callbacks.TensorBoard(log_dir='./99_Logs/fnc-loading'),
             tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix,
                                                save_weights_only=False),
             tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                              min_delta=0.001, 
                                              patience=10, 
                                              verbose=1, 
                                              mode='min',
                                              baseline=None, 
                                              restore_best_weights=True)]

# %%
model.compile(loss='mae', metrics=METRICS, optimizer=optim)

# %%
with tf.device('/GPU:0'):
    hist = model.fit(ds_train,
                     validation_data=ds_val,
                     callbacks=callbacks,
                     epochs=200,
                     verbose=1)
# Out:
# Epoch 1/200
# 54/54 [==============================] - ETA: 0s - loss: 51.6034 - rmse: 53.4380 - mse: 2855.6160 - mae: 51.6034WARNING:tensorflow:From c:\00_data\python38\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_1\assets
# 54/54 [==============================] - 23s 425ms/step - loss: 51.6034 - rmse: 53.4380 - mse: 2855.6160 - mae: 51.6034 - val_loss: 47.1325 - val_rmse: 52.6998 - val_mse: 2777.2717 - val_mae: 47.1325
# Epoch 2/200
# 54/54 [==============================] - ETA: 0s - loss: 50.7221 - rmse: 52.5896 - mse: 2765.6658 - mae: 50.7221INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_2\assets
# 54/54 [==============================] - 21s 387ms/step - loss: 50.7221 - rmse: 52.5896 - mse: 2765.6658 - mae: 50.7221 - val_loss: 47.7312 - val_rmse: 51.1505 - val_mse: 2616.3765 - val_mae: 47.7312
# Epoch 3/200
# 54/54 [==============================] - ETA: 0s - loss: 49.8052 - rmse: 51.7021 - mse: 2673.1096 - mae: 49.8052INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_3\assets
# 54/54 [==============================] - 21s 388ms/step - loss: 49.8052 - rmse: 51.7021 - mse: 2673.1096 - mae: 49.8052 - val_loss: 47.5583 - val_rmse: 50.1720 - val_mse: 2517.2295 - val_mae: 47.5583
# Epoch 4/200
# 54/54 [==============================] - ETA: 0s - loss: 48.8261 - rmse: 50.7611 - mse: 2576.6902 - mae: 48.8261INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_4\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 48.8261 - rmse: 50.7611 - mse: 2576.6902 - mae: 48.8261 - val_loss: 47.2968 - val_rmse: 49.5996 - val_mse: 2460.1226 - val_mae: 47.2968
# Epoch 5/200
# 54/54 [==============================] - ETA: 0s - loss: 47.8157 - rmse: 49.7851 - mse: 2478.5527 - mae: 47.8157INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_5\assets
# 54/54 [==============================] - 20s 369ms/step - loss: 47.8157 - rmse: 49.7851 - mse: 2478.5527 - mae: 47.8157 - val_loss: 46.5977 - val_rmse: 48.8024 - val_mse: 2381.6721 - val_mae: 46.5977
# Epoch 6/200
# 54/54 [==============================] - ETA: 0s - loss: 46.7623 - rmse: 48.7767 - mse: 2379.1653 - mae: 46.7623INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_6\assets
# 54/54 [==============================] - 21s 385ms/step - loss: 46.7623 - rmse: 48.7767 - mse: 2379.1653 - mae: 46.7623 - val_loss: 45.7614 - val_rmse: 47.9429 - val_mse: 2298.5256 - val_mae: 45.7614
# Epoch 7/200
# 54/54 [==============================] - ETA: 0s - loss: 45.6792 - rmse: 47.7360 - mse: 2278.7275 - mae: 45.6792INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_7\assets
# 54/54 [==============================] - 20s 371ms/step - loss: 45.6792 - rmse: 47.7360 - mse: 2278.7275 - mae: 45.6792 - val_loss: 44.7071 - val_rmse: 46.9151 - val_mse: 2201.0239 - val_mae: 44.7071
# Epoch 8/200
# 54/54 [==============================] - ETA: 0s - loss: 44.5524 - rmse: 46.6543 - mse: 2176.6272 - mae: 44.5524INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_8\assets
# 54/54 [==============================] - 20s 376ms/step - loss: 44.5524 - rmse: 46.6543 - mse: 2176.6272 - mae: 44.5524 - val_loss: 43.6921 - val_rmse: 45.9124 - val_mse: 2107.9482 - val_mae: 43.6921
# Epoch 9/200
# 54/54 [==============================] - ETA: 0s - loss: 43.3997 - rmse: 45.5476 - mse: 2074.5864 - mae: 43.3997INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_9\assets
# 54/54 [==============================] - 21s 381ms/step - loss: 43.3997 - rmse: 45.5476 - mse: 2074.5864 - mae: 43.3997 - val_loss: 42.5351 - val_rmse: 44.7855 - val_mse: 2005.7413 - val_mae: 42.5351
# Epoch 10/200
# 54/54 [==============================] - ETA: 0s - loss: 42.1930 - rmse: 44.3958 - mse: 1970.9862 - mae: 42.1930INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_10\assets
# 54/54 [==============================] - 21s 392ms/step - loss: 42.1930 - rmse: 44.3958 - mse: 1970.9862 - mae: 42.1930 - val_loss: 41.3712 - val_rmse: 43.6881 - val_mse: 1908.6521 - val_mae: 41.3712
# Epoch 11/200
# 54/54 [==============================] - ETA: 0s - loss: 40.9783 - rmse: 43.2366 - mse: 1869.4065 - mae: 40.9783INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_11\assets
# 54/54 [==============================] - 20s 373ms/step - loss: 40.9783 - rmse: 43.2366 - mse: 1869.4065 - mae: 40.9783 - val_loss: 40.1280 - val_rmse: 42.5053 - val_mse: 1806.6990 - val_mae: 40.1280
# Epoch 12/200
# 54/54 [==============================] - ETA: 0s - loss: 39.7210 - rmse: 42.0414 - mse: 1767.4763 - mae: 39.7210INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_12\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 39.7210 - rmse: 42.0414 - mse: 1767.4763 - mae: 39.7210 - val_loss: 38.8661 - val_rmse: 41.3193 - val_mse: 1707.2819 - val_mae: 38.8661
# Epoch 13/200
# 54/54 [==============================] - ETA: 0s - loss: 38.4329 - rmse: 40.8135 - mse: 1665.7437 - mae: 38.4329INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_13\assets
# 54/54 [==============================] - 23s 425ms/step - loss: 38.4329 - rmse: 40.8135 - mse: 1665.7437 - mae: 38.4329 - val_loss: 37.6019 - val_rmse: 40.1123 - val_mse: 1608.9930 - val_mae: 37.6019
# Epoch 14/200
# 54/54 [==============================] - ETA: 0s - loss: 37.1210 - rmse: 39.5659 - mse: 1565.4600 - mae: 37.1210INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_14\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 37.1210 - rmse: 39.5659 - mse: 1565.4600 - mae: 37.1210 - val_loss: 36.1959 - val_rmse: 38.7808 - val_mse: 1503.9500 - val_mae: 36.1959
# Epoch 15/200
# 54/54 [==============================] - ETA: 0s - loss: 35.7875 - rmse: 38.2989 - mse: 1466.8075 - mae: 35.7875INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_15\assets
# 54/54 [==============================] - 21s 391ms/step - loss: 35.7875 - rmse: 38.2989 - mse: 1466.8075 - mae: 35.7875 - val_loss: 34.9324 - val_rmse: 37.5644 - val_mse: 1411.0831 - val_mae: 34.9324
# Epoch 16/200
# 54/54 [==============================] - ETA: 0s - loss: 34.4413 - rmse: 37.0179 - mse: 1370.3263 - mae: 34.4413INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_16\assets
# 54/54 [==============================] - 22s 408ms/step - loss: 34.4413 - rmse: 37.0179 - mse: 1370.3263 - mae: 34.4413 - val_loss: 33.5901 - val_rmse: 36.3022 - val_mse: 1317.8496 - val_mae: 33.5901
# Epoch 17/200
# 54/54 [==============================] - ETA: 0s - loss: 33.0721 - rmse: 35.7154 - mse: 1275.5865 - mae: 33.0721INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_17\assets
# 54/54 [==============================] - 21s 395ms/step - loss: 33.0721 - rmse: 35.7154 - mse: 1275.5865 - mae: 33.0721 - val_loss: 32.1648 - val_rmse: 34.9474 - val_mse: 1221.3191 - val_mae: 32.1648
# Epoch 18/200
# 54/54 [==============================] - ETA: 0s - loss: 31.6694 - rmse: 34.3837 - mse: 1182.2366 - mae: 31.6694INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_18\assets
# 54/54 [==============================] - 21s 388ms/step - loss: 31.6694 - rmse: 34.3837 - mse: 1182.2366 - mae: 31.6694 - val_loss: 30.6784 - val_rmse: 33.5377 - val_mse: 1124.7761 - val_mae: 30.6784
# Epoch 19/200
# 54/54 [==============================] - ETA: 0s - loss: 30.2785 - rmse: 33.0676 - mse: 1093.4689 - mae: 30.2785INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_19\assets
# 54/54 [==============================] - 22s 403ms/step - loss: 30.2785 - rmse: 33.0676 - mse: 1093.4689 - mae: 30.2785 - val_loss: 29.3246 - val_rmse: 32.2728 - val_mse: 1041.5320 - val_mae: 29.3246
# Epoch 20/200
# 54/54 [==============================] - ETA: 0s - loss: 28.8600 - rmse: 31.7150 - mse: 1005.8407 - mae: 28.8600INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_20\assets
# 54/54 [==============================] - 22s 400ms/step - loss: 28.8600 - rmse: 31.7150 - mse: 1005.8407 - mae: 28.8600 - val_loss: 27.9618 - val_rmse: 30.9677 - val_mse: 958.9968 - val_mae: 27.9618
# Epoch 21/200
# 54/54 [==============================] - ETA: 0s - loss: 27.4639 - rmse: 30.3760 - mse: 922.6996 - mae: 27.4639INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_21\assets
# 54/54 [==============================] - 22s 408ms/step - loss: 27.4639 - rmse: 30.3760 - mse: 922.6996 - mae: 27.4639 - val_loss: 26.5665 - val_rmse: 29.6409 - val_mse: 878.5853 - val_mae: 26.5665
# Epoch 22/200
# 54/54 [==============================] - ETA: 0s - loss: 26.0569 - rmse: 29.0320 - mse: 842.8582 - mae: 26.0569INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_22\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 26.0569 - rmse: 29.0320 - mse: 842.8582 - mae: 26.0569 - val_loss: 25.2199 - val_rmse: 28.3533 - val_mse: 803.9105 - val_mae: 25.2199
# Epoch 23/200
# 54/54 [==============================] - ETA: 0s - loss: 24.6656 - rmse: 27.6931 - mse: 766.9077 - mae: 24.6656INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_23\assets
# 54/54 [==============================] - 21s 388ms/step - loss: 24.6656 - rmse: 27.6931 - mse: 766.9077 - mae: 24.6656 - val_loss: 23.7397 - val_rmse: 26.9094 - val_mse: 724.1153 - val_mae: 23.7397
# Epoch 24/200
# 54/54 [==============================] - ETA: 0s - loss: 23.2794 - rmse: 26.3474 - mse: 694.1857 - mae: 23.2794INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_24\assets
# 54/54 [==============================] - 21s 387ms/step - loss: 23.2794 - rmse: 26.3474 - mse: 694.1857 - mae: 23.2794 - val_loss: 22.3512 - val_rmse: 25.5585 - val_mse: 653.2392 - val_mae: 22.3512
# Epoch 25/200
# 54/54 [==============================] - ETA: 0s - loss: 21.9484 - rmse: 25.0427 - mse: 627.1356 - mae: 21.9484INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_25\assets
# 54/54 [==============================] - 21s 381ms/step - loss: 21.9484 - rmse: 25.0427 - mse: 627.1356 - mae: 21.9484 - val_loss: 21.0994 - val_rmse: 24.3523 - val_mse: 593.0369 - val_mae: 21.0994
# Epoch 26/200
# 54/54 [==============================] - ETA: 0s - loss: 20.6364 - rmse: 23.7499 - mse: 564.0564 - mae: 20.6364INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_26\assets
# 54/54 [==============================] - 22s 410ms/step - loss: 20.6364 - rmse: 23.7499 - mse: 564.0564 - mae: 20.6364 - val_loss: 19.8140 - val_rmse: 23.0460 - val_mse: 531.1171 - val_mae: 19.8140
# Epoch 27/200
# 54/54 [==============================] - ETA: 0s - loss: 19.3881 - rmse: 22.4945 - mse: 506.0035 - mae: 19.3881INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_27\assets
# 54/54 [==============================] - 21s 386ms/step - loss: 19.3881 - rmse: 22.4945 - mse: 506.0035 - mae: 19.3881 - val_loss: 18.5854 - val_rmse: 21.8172 - val_mse: 475.9885 - val_mae: 18.5854
# Epoch 28/200
# 54/54 [==============================] - ETA: 0s - loss: 18.1609 - rmse: 21.2553 - mse: 451.7859 - mae: 18.1609INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_28\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 18.1609 - rmse: 21.2553 - mse: 451.7859 - mae: 18.1609 - val_loss: 17.4849 - val_rmse: 20.6519 - val_mse: 426.5013 - val_mae: 17.4849
# Epoch 29/200
# 54/54 [==============================] - ETA: 0s - loss: 16.9946 - rmse: 20.0761 - mse: 403.0501 - mae: 16.9946INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_29\assets
# 54/54 [==============================] - 21s 388ms/step - loss: 16.9946 - rmse: 20.0761 - mse: 403.0501 - mae: 16.9946 - val_loss: 16.3731 - val_rmse: 19.5074 - val_mse: 380.5399 - val_mae: 16.3731
# Epoch 30/200
# 54/54 [==============================] - ETA: 0s - loss: 15.8976 - rmse: 18.9534 - mse: 359.2301 - mae: 15.8976INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_30\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 15.8976 - rmse: 18.9534 - mse: 359.2301 - mae: 15.8976 - val_loss: 15.3331 - val_rmse: 18.4275 - val_mse: 339.5738 - val_mae: 15.3331
# Epoch 31/200
# 54/54 [==============================] - ETA: 0s - loss: 14.8760 - rmse: 17.8770 - mse: 319.5881 - mae: 14.8760INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_31\assets
# 54/54 [==============================] - 23s 422ms/step - loss: 14.8760 - rmse: 17.8770 - mse: 319.5881 - mae: 14.8760 - val_loss: 14.3616 - val_rmse: 17.3849 - val_mse: 302.2347 - val_mae: 14.3616
# Epoch 32/200
# 54/54 [==============================] - ETA: 0s - loss: 13.9356 - rmse: 16.8812 - mse: 284.9745 - mae: 13.9356INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_32\assets
# 54/54 [==============================] - 21s 389ms/step - loss: 13.9356 - rmse: 16.8812 - mse: 284.9745 - mae: 13.9356 - val_loss: 13.5332 - val_rmse: 16.4932 - val_mse: 272.0255 - val_mae: 13.5332
# Epoch 33/200
# 54/54 [==============================] - ETA: 0s - loss: 13.0899 - rmse: 15.9747 - mse: 255.1900 - mae: 13.0899INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_33\assets
# 54/54 [==============================] - 21s 390ms/step - loss: 13.0899 - rmse: 15.9747 - mse: 255.1900 - mae: 13.0899 - val_loss: 12.8195 - val_rmse: 15.6965 - val_mse: 246.3796 - val_mae: 12.8195
# Epoch 34/200
# 54/54 [==============================] - ETA: 0s - loss: 12.3363 - rmse: 15.1542 - mse: 229.6502 - mae: 12.3363INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_34\assets
# 54/54 [==============================] - 21s 397ms/step - loss: 12.3363 - rmse: 15.1542 - mse: 229.6502 - mae: 12.3363 - val_loss: 12.0894 - val_rmse: 14.8735 - val_mse: 221.2222 - val_mae: 12.0894
# Epoch 35/200
# 54/54 [==============================] - ETA: 0s - loss: 11.6761 - rmse: 14.4147 - mse: 207.7826 - mae: 11.6761INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_35\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 11.6761 - rmse: 14.4147 - mse: 207.7826 - mae: 11.6761 - val_loss: 11.5570 - val_rmse: 14.2695 - val_mse: 203.6178 - val_mae: 11.5570
# Epoch 36/200
# 54/54 [==============================] - ETA: 0s - loss: 11.1140 - rmse: 13.7864 - mse: 190.0653 - mae: 11.1140INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_36\assets
# 54/54 [==============================] - 21s 392ms/step - loss: 11.1140 - rmse: 13.7864 - mse: 190.0653 - mae: 11.1140 - val_loss: 11.0186 - val_rmse: 13.6595 - val_mse: 186.5827 - val_mae: 11.0186
# Epoch 37/200
# 54/54 [==============================] - ETA: 0s - loss: 10.6502 - rmse: 13.2538 - mse: 175.6620 - mae: 10.6502INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_37\assets
# 54/54 [==============================] - 22s 400ms/step - loss: 10.6502 - rmse: 13.2538 - mse: 175.6620 - mae: 10.6502 - val_loss: 10.6518 - val_rmse: 13.2382 - val_mse: 175.2502 - val_mae: 10.6518
# Epoch 38/200
# 54/54 [==============================] - ETA: 0s - loss: 10.2486 - rmse: 12.7894 - mse: 163.5690 - mae: 10.2486INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_38\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 10.2486 - rmse: 12.7894 - mse: 163.5690 - mae: 10.2486 - val_loss: 10.2523 - val_rmse: 12.7866 - val_mse: 163.4970 - val_mae: 10.2523
# Epoch 39/200
# 54/54 [==============================] - ETA: 0s - loss: 9.9272 - rmse: 12.4201 - mse: 154.2599 - mae: 9.9272INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_39\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 9.9272 - rmse: 12.4201 - mse: 154.2599 - mae: 9.9272 - val_loss: 10.0054 - val_rmse: 12.5276 - val_mse: 156.9402 - val_mae: 10.0054
# Epoch 40/200
# 54/54 [==============================] - ETA: 0s - loss: 9.6682 - rmse: 12.1132 - mse: 146.7286 - mae: 9.6682INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_40\assets
# 54/54 [==============================] - 21s 396ms/step - loss: 9.6682 - rmse: 12.1132 - mse: 146.7286 - mae: 9.6682 - val_loss: 9.7559 - val_rmse: 12.2286 - val_mse: 149.5386 - val_mae: 9.7559
# Epoch 41/200
# 54/54 [==============================] - ETA: 0s - loss: 9.4547 - rmse: 11.8666 - mse: 140.8155 - mae: 9.4547INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_41\assets
# 54/54 [==============================] - 23s 427ms/step - loss: 9.4547 - rmse: 11.8666 - mse: 140.8155 - mae: 9.4547 - val_loss: 9.6121 - val_rmse: 12.0892 - val_mse: 146.1481 - val_mae: 9.6121
# Epoch 42/200
# 54/54 [==============================] - ETA: 0s - loss: 9.2828 - rmse: 11.6673 - mse: 136.1251 - mae: 9.2828INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_42\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 9.2828 - rmse: 11.6673 - mse: 136.1251 - mae: 9.2828 - val_loss: 9.4354 - val_rmse: 11.8791 - val_mse: 141.1128 - val_mae: 9.4354
# Epoch 43/200
# 54/54 [==============================] - ETA: 0s - loss: 9.1558 - rmse: 11.5198 - mse: 132.7057 - mae: 9.1558INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_43\assets
# 54/54 [==============================] - 21s 387ms/step - loss: 9.1558 - rmse: 11.5198 - mse: 132.7057 - mae: 9.1558 - val_loss: 9.3389 - val_rmse: 11.7744 - val_mse: 138.6356 - val_mae: 9.3389
# Epoch 44/200
# 54/54 [==============================] - ETA: 0s - loss: 9.0626 - rmse: 11.4177 - mse: 130.3639 - mae: 9.0626INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_44\assets
# 54/54 [==============================] - 21s 397ms/step - loss: 9.0626 - rmse: 11.4177 - mse: 130.3639 - mae: 9.0626 - val_loss: 9.2117 - val_rmse: 11.6381 - val_mse: 135.4446 - val_mae: 9.2117
# Epoch 45/200
# 54/54 [==============================] - ETA: 0s - loss: 8.9766 - rmse: 11.3146 - mse: 128.0201 - mae: 8.9766INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_45\assets
# 54/54 [==============================] - 21s 396ms/step - loss: 8.9766 - rmse: 11.3146 - mse: 128.0201 - mae: 8.9766 - val_loss: 9.1927 - val_rmse: 11.6176 - val_mse: 134.9677 - val_mae: 9.1927
# Epoch 46/200
# 54/54 [==============================] - ETA: 0s - loss: 8.9126 - rmse: 11.2479 - mse: 126.5162 - mae: 8.9126INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_46\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 8.9126 - rmse: 11.2479 - mse: 126.5162 - mae: 8.9126 - val_loss: 9.1507 - val_rmse: 11.5607 - val_mse: 133.6491 - val_mae: 9.1507
# Epoch 47/200
# 54/54 [==============================] - ETA: 0s - loss: 8.8726 - rmse: 11.1991 - mse: 125.4191 - mae: 8.8726INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_47\assets
# 54/54 [==============================] - 21s 388ms/step - loss: 8.8726 - rmse: 11.1991 - mse: 125.4191 - mae: 8.8726 - val_loss: 9.0770 - val_rmse: 11.5051 - val_mse: 132.3681 - val_mae: 9.0770
# Epoch 48/200
# 54/54 [==============================] - ETA: 0s - loss: 8.8156 - rmse: 11.1389 - mse: 124.0741 - mae: 8.8156INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_48\assets
# 54/54 [==============================] - 22s 411ms/step - loss: 8.8156 - rmse: 11.1389 - mse: 124.0741 - mae: 8.8156 - val_loss: 9.0241 - val_rmse: 11.4388 - val_mse: 130.8472 - val_mae: 9.0241
# Epoch 49/200
# 54/54 [==============================] - ETA: 0s - loss: 8.7921 - rmse: 11.1279 - mse: 123.8301 - mae: 8.7921INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_49\assets
# 54/54 [==============================] - 22s 409ms/step - loss: 8.7921 - rmse: 11.1279 - mse: 123.8301 - mae: 8.7921 - val_loss: 9.0281 - val_rmse: 11.4403 - val_mse: 130.8814 - val_mae: 9.0281
# Epoch 50/200
# 54/54 [==============================] - ETA: 0s - loss: 8.7699 - rmse: 11.1050 - mse: 123.3214 - mae: 8.7699INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_50\assets
# 54/54 [==============================] - 22s 406ms/step - loss: 8.7699 - rmse: 11.1050 - mse: 123.3214 - mae: 8.7699 - val_loss: 9.0419 - val_rmse: 11.4565 - val_mse: 131.2520 - val_mae: 9.0419
# Epoch 51/200
# 54/54 [==============================] - ETA: 0s - loss: 8.7467 - rmse: 11.0868 - mse: 122.9174 - mae: 8.7467INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_51\assets
# 54/54 [==============================] - 21s 396ms/step - loss: 8.7467 - rmse: 11.0868 - mse: 122.9174 - mae: 8.7467 - val_loss: 9.0007 - val_rmse: 11.4138 - val_mse: 130.2740 - val_mae: 9.0007
# Epoch 52/200
# 54/54 [==============================] - ETA: 0s - loss: 8.7135 - rmse: 11.0524 - mse: 122.1559 - mae: 8.7135INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_52\assets
# 54/54 [==============================] - 21s 389ms/step - loss: 8.7135 - rmse: 11.0524 - mse: 122.1559 - mae: 8.7135 - val_loss: 8.9788 - val_rmse: 11.3850 - val_mse: 129.6174 - val_mae: 8.9788
# Epoch 53/200
# 54/54 [==============================] - ETA: 0s - loss: 8.7045 - rmse: 11.0499 - mse: 122.0997 - mae: 8.7045INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_53\assets
# 54/54 [==============================] - 21s 397ms/step - loss: 8.7045 - rmse: 11.0499 - mse: 122.0997 - mae: 8.7045 - val_loss: 8.9644 - val_rmse: 11.3741 - val_mse: 129.3693 - val_mae: 8.9644
# Epoch 54/200
# 54/54 [==============================] - ETA: 0s - loss: 8.6724 - rmse: 11.0188 - mse: 121.4146 - mae: 8.6724INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_54\assets
# 54/54 [==============================] - 21s 391ms/step - loss: 8.6724 - rmse: 11.0188 - mse: 121.4146 - mae: 8.6724 - val_loss: 9.0377 - val_rmse: 11.4512 - val_mse: 131.1305 - val_mae: 9.0377
# Epoch 55/200
# 54/54 [==============================] - ETA: 0s - loss: 8.6650 - rmse: 11.0169 - mse: 121.3726 - mae: 8.6650INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_55\assets
# 54/54 [==============================] - 21s 388ms/step - loss: 8.6650 - rmse: 11.0169 - mse: 121.3726 - mae: 8.6650 - val_loss: 9.0014 - val_rmse: 11.4195 - val_mse: 130.4059 - val_mae: 9.0014
# Epoch 56/200
# 54/54 [==============================] - ETA: 0s - loss: 8.6471 - rmse: 10.9962 - mse: 120.9165 - mae: 8.6471INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_56\assets
# 54/54 [==============================] - 21s 391ms/step - loss: 8.6471 - rmse: 10.9962 - mse: 120.9165 - mae: 8.6471 - val_loss: 9.0136 - val_rmse: 11.4277 - val_mse: 130.5914 - val_mae: 9.0136
# Epoch 57/200
# 54/54 [==============================] - ETA: 0s - loss: 8.6360 - rmse: 10.9861 - mse: 120.6938 - mae: 8.6360INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_57\assets
# 54/54 [==============================] - 21s 397ms/step - loss: 8.6360 - rmse: 10.9861 - mse: 120.6938 - mae: 8.6360 - val_loss: 8.9660 - val_rmse: 11.3838 - val_mse: 129.5898 - val_mae: 8.9660
# Epoch 58/200
# 54/54 [==============================] - ETA: 0s - loss: 8.6147 - rmse: 10.9693 - mse: 120.3245 - mae: 8.6147INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_58\assets
# 54/54 [==============================] - 21s 390ms/step - loss: 8.6147 - rmse: 10.9693 - mse: 120.3245 - mae: 8.6147 - val_loss: 8.9678 - val_rmse: 11.3848 - val_mse: 129.6130 - val_mae: 8.9678
# Epoch 59/200
# 54/54 [==============================] - ETA: 0s - loss: 8.6048 - rmse: 10.9679 - mse: 120.2940 - mae: 8.6048INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_59\assets
# 54/54 [==============================] - 21s 389ms/step - loss: 8.6048 - rmse: 10.9679 - mse: 120.2940 - mae: 8.6048 - val_loss: 9.0075 - val_rmse: 11.4141 - val_mse: 130.2819 - val_mae: 9.0075
# Epoch 60/200
# 54/54 [==============================] - ETA: 0s - loss: 8.6004 - rmse: 10.9607 - mse: 120.1359 - mae: 8.6004INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_60\assets
# 54/54 [==============================] - 22s 400ms/step - loss: 8.6004 - rmse: 10.9607 - mse: 120.1359 - mae: 8.6004 - val_loss: 8.9575 - val_rmse: 11.3760 - val_mse: 129.4145 - val_mae: 8.9575
# Epoch 61/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5855 - rmse: 10.9493 - mse: 119.8867 - mae: 8.5855INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_61\assets
# 54/54 [==============================] - 21s 393ms/step - loss: 8.5855 - rmse: 10.9493 - mse: 119.8867 - mae: 8.5855 - val_loss: 8.9034 - val_rmse: 11.3177 - val_mse: 128.0900 - val_mae: 8.9034
# Epoch 62/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5804 - rmse: 10.9434 - mse: 119.7590 - mae: 8.5804INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_62\assets
# 54/54 [==============================] - 21s 392ms/step - loss: 8.5804 - rmse: 10.9434 - mse: 119.7590 - mae: 8.5804 - val_loss: 8.9019 - val_rmse: 11.3015 - val_mse: 127.7241 - val_mae: 8.9019
# Epoch 63/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5600 - rmse: 10.9213 - mse: 119.2747 - mae: 8.5600INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_63\assets
# 54/54 [==============================] - 21s 391ms/step - loss: 8.5600 - rmse: 10.9213 - mse: 119.2747 - mae: 8.5600 - val_loss: 8.9252 - val_rmse: 11.3568 - val_mse: 128.9767 - val_mae: 8.9252
# Epoch 64/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5389 - rmse: 10.9042 - mse: 118.9008 - mae: 8.5389INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_64\assets
# 54/54 [==============================] - 21s 392ms/step - loss: 8.5389 - rmse: 10.9042 - mse: 118.9008 - mae: 8.5389 - val_loss: 8.9007 - val_rmse: 11.3048 - val_mse: 127.7989 - val_mae: 8.9007
# Epoch 65/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5293 - rmse: 10.8970 - mse: 118.7455 - mae: 8.5293INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_65\assets
# 54/54 [==============================] - 21s 393ms/step - loss: 8.5293 - rmse: 10.8970 - mse: 118.7455 - mae: 8.5293 - val_loss: 8.9359 - val_rmse: 11.3677 - val_mse: 129.2246 - val_mae: 8.9359
# Epoch 66/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5246 - rmse: 10.8897 - mse: 118.5863 - mae: 8.5246INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_66\assets
# 54/54 [==============================] - 22s 399ms/step - loss: 8.5246 - rmse: 10.8897 - mse: 118.5863 - mae: 8.5246 - val_loss: 8.9170 - val_rmse: 11.3227 - val_mse: 128.2039 - val_mae: 8.9170
# Epoch 67/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5151 - rmse: 10.8881 - mse: 118.5508 - mae: 8.5151INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_67\assets
# 54/54 [==============================] - 21s 392ms/step - loss: 8.5151 - rmse: 10.8881 - mse: 118.5508 - mae: 8.5151 - val_loss: 8.8834 - val_rmse: 11.2988 - val_mse: 127.6629 - val_mae: 8.8834
# Epoch 68/200
# 54/54 [==============================] - ETA: 0s - loss: 8.5054 - rmse: 10.8787 - mse: 118.3462 - mae: 8.5054- ETA: 4s - loss: 8.4299 - rmse: 10.7752 - mse: 11INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_68\assets
# 54/54 [==============================] - 21s 393ms/step - loss: 8.5054 - rmse: 10.8787 - mse: 118.3462 - mae: 8.5054 - val_loss: 8.8926 - val_rmse: 11.3041 - val_mse: 127.7824 - val_mae: 8.8926
# Epoch 69/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4899 - rmse: 10.8683 - mse: 118.1195 - mae: 8.4899INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_69\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 8.4899 - rmse: 10.8683 - mse: 118.1195 - mae: 8.4899 - val_loss: 8.9370 - val_rmse: 11.3581 - val_mse: 129.0058 - val_mae: 8.9370
# Epoch 70/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4725 - rmse: 10.8526 - mse: 117.7794 - mae: 8.4725INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_70\assets
# 54/54 [==============================] - 21s 391ms/step - loss: 8.4725 - rmse: 10.8526 - mse: 117.7794 - mae: 8.4725 - val_loss: 8.9055 - val_rmse: 11.2981 - val_mse: 127.6479 - val_mae: 8.9055
# Epoch 71/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4738 - rmse: 10.8585 - mse: 117.9072 - mae: 8.4738INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_71\assets
# 54/54 [==============================] - 22s 406ms/step - loss: 8.4738 - rmse: 10.8585 - mse: 117.9072 - mae: 8.4738 - val_loss: 8.9150 - val_rmse: 11.3267 - val_mse: 128.2950 - val_mae: 8.9150
# Epoch 72/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4427 - rmse: 10.8317 - mse: 117.3255 - mae: 8.4427INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_72\assets
# 54/54 [==============================] - 21s 397ms/step - loss: 8.4427 - rmse: 10.8317 - mse: 117.3255 - mae: 8.4427 - val_loss: 8.9100 - val_rmse: 11.3284 - val_mse: 128.3327 - val_mae: 8.9100
# Epoch 73/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4332 - rmse: 10.8162 - mse: 116.9910 - mae: 8.4332INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_73\assets
# 54/54 [==============================] - 21s 397ms/step - loss: 8.4332 - rmse: 10.8162 - mse: 116.9910 - mae: 8.4332 - val_loss: 8.9257 - val_rmse: 11.3400 - val_mse: 128.5961 - val_mae: 8.9257
# Epoch 74/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4415 - rmse: 10.8257 - mse: 117.1949 - mae: 8.4415INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_74\assets
# 54/54 [==============================] - 21s 390ms/step - loss: 8.4415 - rmse: 10.8257 - mse: 117.1949 - mae: 8.4415 - val_loss: 8.9073 - val_rmse: 11.3150 - val_mse: 128.0289 - val_mae: 8.9073
# Epoch 75/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4345 - rmse: 10.8248 - mse: 117.1773 - mae: 8.4345INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_75\assets
# 54/54 [==============================] - 22s 412ms/step - loss: 8.4345 - rmse: 10.8248 - mse: 117.1773 - mae: 8.4345 - val_loss: 8.8918 - val_rmse: 11.3025 - val_mse: 127.7466 - val_mae: 8.8918
# Epoch 76/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4304 - rmse: 10.8160 - mse: 116.9862 - mae: 8.4304INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_76\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 8.4304 - rmse: 10.8160 - mse: 116.9862 - mae: 8.4304 - val_loss: 8.9221 - val_rmse: 11.3336 - val_mse: 128.4500 - val_mae: 8.9221
# Epoch 77/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4083 - rmse: 10.8060 - mse: 116.7688 - mae: 8.4083INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_77\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 8.4083 - rmse: 10.8060 - mse: 116.7688 - mae: 8.4083 - val_loss: 8.8796 - val_rmse: 11.2928 - val_mse: 127.5265 - val_mae: 8.8796
# Epoch 78/200
# 54/54 [==============================] - ETA: 0s - loss: 8.4106 - rmse: 10.8009 - mse: 116.6600 - mae: 8.4106INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_78\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 8.4106 - rmse: 10.8009 - mse: 116.6600 - mae: 8.4106 - val_loss: 8.9076 - val_rmse: 11.3156 - val_mse: 128.0425 - val_mae: 8.9076
# Epoch 79/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3946 - rmse: 10.7948 - mse: 116.5270 - mae: 8.3946INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_79\assets
# 54/54 [==============================] - 21s 394ms/step - loss: 8.3946 - rmse: 10.7948 - mse: 116.5270 - mae: 8.3946 - val_loss: 8.9084 - val_rmse: 11.3070 - val_mse: 127.8480 - val_mae: 8.9084
# Epoch 80/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3942 - rmse: 10.7898 - mse: 116.4196 - mae: 8.3942INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_80\assets
# 54/54 [==============================] - 21s 395ms/step - loss: 8.3942 - rmse: 10.7898 - mse: 116.4196 - mae: 8.3942 - val_loss: 8.8728 - val_rmse: 11.2716 - val_mse: 127.0501 - val_mae: 8.8728
# Epoch 81/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3642 - rmse: 10.7593 - mse: 115.7627 - mae: 8.3642INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_81\assets
# 54/54 [==============================] - 21s 396ms/step - loss: 8.3642 - rmse: 10.7593 - mse: 115.7627 - mae: 8.3642 - val_loss: 8.9032 - val_rmse: 11.3124 - val_mse: 127.9704 - val_mae: 8.9032
# Epoch 82/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3611 - rmse: 10.7578 - mse: 115.7308 - mae: 8.3611INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_82\assets
# 54/54 [==============================] - 21s 381ms/step - loss: 8.3611 - rmse: 10.7578 - mse: 115.7308 - mae: 8.3611 - val_loss: 8.8995 - val_rmse: 11.2835 - val_mse: 127.3184 - val_mae: 8.8995
# Epoch 83/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3503 - rmse: 10.7446 - mse: 115.4472 - mae: 8.3503INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_83\assets
# 54/54 [==============================] - 22s 405ms/step - loss: 8.3503 - rmse: 10.7446 - mse: 115.4472 - mae: 8.3503 - val_loss: 8.8921 - val_rmse: 11.2925 - val_mse: 127.5208 - val_mae: 8.8921
# Epoch 84/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3512 - rmse: 10.7513 - mse: 115.5903 - mae: 8.3512INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_84\assets
# 54/54 [==============================] - 22s 398ms/step - loss: 8.3512 - rmse: 10.7513 - mse: 115.5903 - mae: 8.3512 - val_loss: 8.9075 - val_rmse: 11.3164 - val_mse: 128.0604 - val_mae: 8.9075
# Epoch 85/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3422 - rmse: 10.7468 - mse: 115.4937 - mae: 8.3422INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_85\assets
# 54/54 [==============================] - 21s 390ms/step - loss: 8.3422 - rmse: 10.7468 - mse: 115.4937 - mae: 8.3422 - val_loss: 8.8447 - val_rmse: 11.2288 - val_mse: 126.0869 - val_mae: 8.8447
# Epoch 86/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3348 - rmse: 10.7410 - mse: 115.3682 - mae: 8.3348INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_86\assets
# 54/54 [==============================] - 22s 407ms/step - loss: 8.3348 - rmse: 10.7410 - mse: 115.3682 - mae: 8.3348 - val_loss: 8.9200 - val_rmse: 11.3195 - val_mse: 128.1310 - val_mae: 8.9200
# Epoch 87/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3274 - rmse: 10.7196 - mse: 114.9108 - mae: 8.3274INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_87\assets
# 54/54 [==============================] - 21s 385ms/step - loss: 8.3274 - rmse: 10.7196 - mse: 114.9108 - mae: 8.3274 - val_loss: 8.8850 - val_rmse: 11.2947 - val_mse: 127.5700 - val_mae: 8.8850
# Epoch 88/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3197 - rmse: 10.7254 - mse: 115.0346 - mae: 8.3197INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_88\assets
# 54/54 [==============================] - 22s 408ms/step - loss: 8.3197 - rmse: 10.7254 - mse: 115.0346 - mae: 8.3197 - val_loss: 8.8876 - val_rmse: 11.2943 - val_mse: 127.5619 - val_mae: 8.8876
# Epoch 89/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3137 - rmse: 10.7229 - mse: 114.9797 - mae: 8.3137INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_89\assets
# 54/54 [==============================] - 21s 383ms/step - loss: 8.3137 - rmse: 10.7229 - mse: 114.9797 - mae: 8.3137 - val_loss: 8.9073 - val_rmse: 11.3193 - val_mse: 128.1268 - val_mae: 8.9073
# Epoch 90/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3021 - rmse: 10.7128 - mse: 114.7643 - mae: 8.3021INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_90\assets
# 54/54 [==============================] - 21s 398ms/step - loss: 8.3021 - rmse: 10.7128 - mse: 114.7643 - mae: 8.3021 - val_loss: 8.8957 - val_rmse: 11.2926 - val_mse: 127.5233 - val_mae: 8.8957
# Epoch 91/200
# 54/54 [==============================] - ETA: 0s - loss: 8.3045 - rmse: 10.7088 - mse: 114.6783 - mae: 8.3045INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_91\assets
# 54/54 [==============================] - 21s 396ms/step - loss: 8.3045 - rmse: 10.7088 - mse: 114.6783 - mae: 8.3045 - val_loss: 8.9003 - val_rmse: 11.2953 - val_mse: 127.5841 - val_mae: 8.9003
# Epoch 92/200
# 54/54 [==============================] - ETA: 0s - loss: 8.2991 - rmse: 10.7079 - mse: 114.6594 - mae: 8.2991INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_92\assets
# 54/54 [==============================] - 22s 408ms/step - loss: 8.2991 - rmse: 10.7079 - mse: 114.6594 - mae: 8.2991 - val_loss: 8.8852 - val_rmse: 11.2805 - val_mse: 127.2501 - val_mae: 8.8852
# Epoch 93/200
# 54/54 [==============================] - ETA: 0s - loss: 8.2902 - rmse: 10.7009 - mse: 114.5102 - mae: 8.2902INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_93\assets
# 54/54 [==============================] - 21s 384ms/step - loss: 8.2902 - rmse: 10.7009 - mse: 114.5102 - mae: 8.2902 - val_loss: 8.8647 - val_rmse: 11.2564 - val_mse: 126.7073 - val_mae: 8.8647
# Epoch 94/200
# 54/54 [==============================] - ETA: 0s - loss: 8.2870 - rmse: 10.6929 - mse: 114.3374 - mae: 8.2870INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_94\assets
# 54/54 [==============================] - 21s 395ms/step - loss: 8.2870 - rmse: 10.6929 - mse: 114.3374 - mae: 8.2870 - val_loss: 8.9131 - val_rmse: 11.3170 - val_mse: 128.0747 - val_mae: 8.9131
# Epoch 95/200
# 54/54 [==============================] - ETA: 0s - loss: 8.2635 - rmse: 10.6820 - mse: 114.1057 - mae: 8.2635INFO:tensorflow:Assets written to: ./99_Training_checkpoints/fnc-loading\ckpt_95\assets
# Restoring model weights from the end of the best epoch.
# 54/54 [==============================] - 21s 395ms/step - loss: 8.2635 - rmse: 10.6820 - mse: 114.1057 - mae: 8.2635 - val_loss: 8.8958 - val_rmse: 11.3057 - val_mse: 127.8197 - val_mae: 8.8958
# Epoch 00095: early stopping

# %%
with tf.device('/GPU:0'):
    results = model.evaluate(ds_test, verbose=1)
# Out:
# 16/16 [==============================] - 3s 197ms/step - loss: 8.8845 - rmse: 11.2428 - mse: 126.4005 - mae: 8.8845 0s - loss: 8.8692 - rmse: 11.2089 - mse: 125.6403 - mae: 8.86

# %%
    fig = plt.figure()
    fig.set_size_inches(16,16)

    ax=fig.add_subplot(3,2,1)
    ax.plot(hist.history['rmse'])
    ax.plot(hist.history['mse'])
    ax.legend(['Metric', 'Loss'])
    ax.set_title('Train')

    ax=fig.add_subplot(3,2,2)
    ax.plot(hist.history['val_rmse'])
    ax.plot(hist.history['val_mse'])
    ax.legend(['Metric', 'Loss'])
    ax.set_title('Test')

    ax=fig.add_subplot(3,2,3)
    ax.plot(hist.history['loss'])
    ax.plot(hist.history['val_loss'])
    ax.legend(['Train', 'Test'])
    ax.set_title('Loss')

    ax=fig.add_subplot(3,2,4)
    ax.plot(hist.history['mse'])
    ax.plot(hist.history['val_mse'])
    ax.legend(['Train', 'Test'])
    ax.set_title('Metric')
# Out:
# Text(0.5, 1.0, 'Metric')

# %%
X1_test = pd.read_csv('00_Data/fnc.csv')
X1_test = X1_test[X1_test['Id'].isin(TEST_IDS)]
X1_test = X1_test.to_numpy()
X1_test = X1_test[:,1:]

# %%
X2_test = pd.read_csv('00_Data/loading.csv')
X2_test = X2_test[X2_test['Id'].isin(TEST_IDS)]
X2_test = X2_test.to_numpy()
X2_test = X2_test[:,1:]

# %%
y_preds = model.predict([X1_test, X2_test])

# %%
y_preds = y_preds.flatten()

# %%
df_submission = []
i = 0
for idx in TEST_IDS:
    df_submission.append(['{0}_age'.format(idx), y_preds[i]])
    df_submission.append(['{0}_domain1_var1'.format(idx), y_preds[i+1]])
    df_submission.append(['{0}_domain1_var2'.format(idx), y_preds[i+2]])
    df_submission.append(['{0}_domain2_var1'.format(idx), y_preds[i+3]])
    df_submission.append(['{0}_domain2_var2'.format(idx), y_preds[i+4]])
    i += 5

df_submission = pd.DataFrame(df_submission, columns=['Id', 'Predicted'])

# %%
df_submission.to_csv('submission_fnc-load_mae_04.csv', index=False)

# %%
data = pd.read_csv('00_Data/train_scores.csv')
data
# Out:
#          Id        age  domain1_var1  domain1_var2  domain2_var1  domain2_var2
# 0     10001  57.436077     30.571975     62.553736     53.325130     51.427998
# 1     10002  59.580851     50.969456     67.470628     60.651856     58.311361
# 2     10004  71.413018     53.152498     58.012103     52.418389     62.536641
# 3     10005  66.532630           NaN           NaN     52.108977     69.993075
# 4     10007  38.617381     49.197021     65.674285     40.151376     34.096421
# ...     ...        ...           ...           ...           ...           ...
# 5872  21746  14.257265     21.358872     61.165998     51.778483     54.640179
# 5873  21747  55.456978     68.169675     29.907995     55.349257     54.019517
# 5874  21750  48.948756     55.114811     60.878271     38.617246     50.679885
# 5875  21752  66.532630     59.844808     72.303110     55.458281     46.870235
# 5876  21754  68.820928     56.594193     34.605868     49.922535     50.383078
#
# [5877 rows x 6 columns]

# %%
data_nulls = data[data.isnull().any(axis=1)]
NULL_IDS = list(data_nulls['Id'].values)
